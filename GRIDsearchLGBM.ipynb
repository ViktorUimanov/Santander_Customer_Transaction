# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold
import lightgbm as lgb

# %%
import os
os.chdir('/content/drive/MyDrive/sasha_babuin/data_santander')

# %%
train_df = pd.read_csv('data/train 2.csv')
test_df = pd.read_csv('data/test.csv')
X = train_df.drop(['ID_code', 'target'], axis = 1)
y = train_df['target']
test_df.drop(['ID_code'], axis = 1, inplace = True)
scaler = MinMaxScaler()
scaler.fit(X)
scaler.fit(test_df)
X = pd.DataFrame(scaler.transform(X), columns = X.columns)
test_df = pd.DataFrame(scaler.transform(test_df), columns = test_df.columns)

# %%
param_initial = {
    'bagging_freq': 5,
    'bagging_fraction': 0.5, ## 
    'boost_from_average': False, ## 
    'boost': 'gbdt', ## 
    'feature_fraction': 0.1, ##
    'learning_rate': 0.01, 
    'max_depth': 5,  
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 16,
    'tree_learner': 'serial',
    'objective': 'binary'
}

# %%
skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 102)

res_val = np.zeros(len(train_df))
predictions = np.zeros(len(test_df))
results = pd.DataFrame()
features = X.columns.to_list()

for fold_, (train_idx, val_idx) in enumerate(skf.split(X.values, y.values)):
    print("Fold {}".format(fold_))
    trn_data = lgb.Dataset(X.iloc[train_idx], label=y.iloc[train_idx])
    val_data = lgb.Dataset(X.iloc[val_idx], label=y.iloc[val_idx])

    lgbt = lgb.train(param_initial, trn_data, num_boost_round = 500_000,
                    valid_sets = [trn_data, val_data], early_stopping_rounds = 3000, 
                     verbose_eval=1000)
    predictions_fold = lgbt.predict(X.iloc[val_idx])

    res_val[val_idx] = predictions_fold

    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = features
    fold_importance_df["importance"] = lgbt.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([results, fold_importance_df], axis=0)

    predictions += lgbt.predict(test_df[features], num_iteration=lgbt.best_iteration)


predictions_df = pd.DataFrame({'ID_code' : test_df['ID_code'].values})
predictions_df['predictions'] = predictions
# Out:
# Fold 0
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.892997	valid_1's auc: 0.864831
# [2000]	training's auc: 0.916541	valid_1's auc: 0.882353
# [3000]	training's auc: 0.929253	valid_1's auc: 0.89013
# [4000]	training's auc: 0.937398	valid_1's auc: 0.894231
# [5000]	training's auc: 0.943616	valid_1's auc: 0.896157
# [6000]	training's auc: 0.948817	valid_1's auc: 0.89713
# [7000]	training's auc: 0.953572	valid_1's auc: 0.897459
# [8000]	training's auc: 0.957841	valid_1's auc: 0.897496
# [9000]	training's auc: 0.961867	valid_1's auc: 0.897533
# [10000]	training's auc: 0.965636	valid_1's auc: 0.897325
# [11000]	training's auc: 0.969205	valid_1's auc: 0.897325
# [12000]	training's auc: 0.972525	valid_1's auc: 0.897014
# Early stopping, best iteration is:
# [9050]	training's auc: 0.962065	valid_1's auc: 0.897571
# Fold 1
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.892248	valid_1's auc: 0.867219
# [2000]	training's auc: 0.916121	valid_1's auc: 0.883687
# [3000]	training's auc: 0.929067	valid_1's auc: 0.891408
# [4000]	training's auc: 0.937392	valid_1's auc: 0.894799
# [5000]	training's auc: 0.943689	valid_1's auc: 0.896374
# [6000]	training's auc: 0.948868	valid_1's auc: 0.896918
# [7000]	training's auc: 0.953553	valid_1's auc: 0.897404
# [8000]	training's auc: 0.957835	valid_1's auc: 0.897545
# [9000]	training's auc: 0.961903	valid_1's auc: 0.897687
# [10000]	training's auc: 0.965672	valid_1's auc: 0.897593
# [11000]	training's auc: 0.969136	valid_1's auc: 0.897451
# Early stopping, best iteration is:
# [8665]	training's auc: 0.960594	valid_1's auc: 0.897774
# Fold 2
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.893107	valid_1's auc: 0.864641
# [2000]	training's auc: 0.916438	valid_1's auc: 0.882668
# [3000]	training's auc: 0.929188	valid_1's auc: 0.890414
# [4000]	training's auc: 0.93739	valid_1's auc: 0.89416
# [5000]	training's auc: 0.943474	valid_1's auc: 0.895904
# [6000]	training's auc: 0.948753	valid_1's auc: 0.896938
# [7000]	training's auc: 0.95341	valid_1's auc: 0.897384
# [8000]	training's auc: 0.957726	valid_1's auc: 0.897649
# [9000]	training's auc: 0.961691	valid_1's auc: 0.897801
# [10000]	training's auc: 0.965544	valid_1's auc: 0.897747
# [11000]	training's auc: 0.969113	valid_1's auc: 0.89771
# Early stopping, best iteration is:
# [8732]	training's auc: 0.96069	valid_1's auc: 0.897826
# Fold 3
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.891512	valid_1's auc: 0.869737
# [2000]	training's auc: 0.915215	valid_1's auc: 0.887149
# [3000]	training's auc: 0.928334	valid_1's auc: 0.89518
# [4000]	training's auc: 0.936613	valid_1's auc: 0.898724
# [5000]	training's auc: 0.943009	valid_1's auc: 0.900443
# [6000]	training's auc: 0.94828	valid_1's auc: 0.901418
# [7000]	training's auc: 0.952934	valid_1's auc: 0.901676
# [8000]	training's auc: 0.957286	valid_1's auc: 0.901896
# [9000]	training's auc: 0.961389	valid_1's auc: 0.901908
# [10000]	training's auc: 0.965208	valid_1's auc: 0.90178
# Early stopping, best iteration is:
# [7806]	training's auc: 0.956467	valid_1's auc: 0.901933
# Fold 4
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.891305	valid_1's auc: 0.871291
# [2000]	training's auc: 0.915111	valid_1's auc: 0.888418
# [3000]	training's auc: 0.928048	valid_1's auc: 0.896095
# [4000]	training's auc: 0.936444	valid_1's auc: 0.899665
# [5000]	training's auc: 0.942712	valid_1's auc: 0.901338
# [6000]	training's auc: 0.94792	valid_1's auc: 0.902075
# [7000]	training's auc: 0.952622	valid_1's auc: 0.902318
# [8000]	training's auc: 0.956885	valid_1's auc: 0.902272
# [9000]	training's auc: 0.961007	valid_1's auc: 0.9023
# [10000]	training's auc: 0.964855	valid_1's auc: 0.902201
# Early stopping, best iteration is:
# [7134]	training's auc: 0.953205	valid_1's auc: 0.902355
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ID_code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-1227f3afa8aa> in <module>
#      27
#      28
# ---> 29 predictions_df = pd.DataFrame({'ID_code' : test_df['ID_code'].values})
#      30 predictions_df['predictions'] = predictions
#      31
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'ID_code'

# %%
import joblib
# save model
joblib.dump(gcv.best_estimator_, 'lgb.pkl')
# load model

# %%
predictions_df = pd.DataFrame(test_df)
predictions_df['predictions'] = predictions

# %%
predictions_df['predictions'] = predictions_df['predictions'] / 5

# %%
predictions_df = predictions_df['predictions']

# %%
predictions_df
# Out:
# 0         0.086863
# 1         0.207560
# 2         0.187246
# 3         0.197280
# 4         0.041279
#             ...
# 199995    0.033802
# 199996    0.007421
# 199997    0.004043
# 199998    0.086295
# 199999    0.059993
# Name: predictions, Length: 200000, dtype: float64

# %%
roc_auc_score(y, res_val)
# Out:
# 0.8994517978181329

# %%
predictions_df.to_csv('test_gb.csv')

# %%
predictions_vsl = pd.DataFrame({'ID_code' : train_df['ID_code'].values})

# %%
predictions_vsl['prediction'] = res_val
predictions_vsl
# Out:
#              ID_code  prediction
# 0            train_0    0.009666
# 1            train_1    0.350433
# 2            train_2    0.007575
# 3            train_3    0.233441
# 4            train_4    0.084524
# ...              ...         ...
# 199995  train_199995    0.083923
# 199996  train_199996    0.044822
# 199997  train_199997    0.046748
# 199998  train_199998    0.047308
# 199999  train_199999    0.007518
#
# [200000 rows x 2 columns]

# %%
predictions_vsl.to_csv('train_gb.csv')

# %%
predictions_vsl
# Out:
#              ID_code  prediction
# 0            train_0    0.009666
# 1            train_1    0.350433
# 2            train_2    0.007575
# 3            train_3    0.233441
# 4            train_4    0.084524
# ...              ...         ...
# 199995  train_199995    0.083923
# 199996  train_199996    0.044822
# 199997  train_199997    0.046748
# 199998  train_199998    0.047308
# 199999  train_199999    0.007518
#
# [200000 rows x 2 columns]
